# %%
import matplotlib
from pylab import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# here matplotlib,pylab,numpy are the pakages requried for working on graphs

# %%
x = np.linspace(0, 10,10)
y = x ** 2
y1 = x ** (0.5)

# %% [markdown]
# linespace function stored in numpy

# %%
figure1()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('graph')

# %%
show()

# %% [markdown]
# it work similar to matlab,just we have to add show() fuction to give output

# %%
subplot(2,1,1)
plot(x,y,"r--")
title('x,y')
subplot(2,1,2)
plot(x,y1,"r*-")
title('x,y1')

# %%
show()

# %%
fig = plt.figure()

axes = fig.add_axes([0.2, 0.2,0.8,0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');
show()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');
show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
show()

# %%
ig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    
fig.tight_layout()
show()
